# %% [markdown]
# #    Ciência dos Dados - Projeto 1

# %% [markdown]
# # Nome - Luigi Portugal Gouvêa Consonni

# %% [markdown]
#  <h3>- Variáveis escolhidas:</h3>
#  <ol>
#     <li>IDH</li>
#   <li>Taxa de cresciemento populacional / ano</li>
#   <li>Preço gasolina/Litro</li>
#  </ol>
#  <h3>- Pergunta norteadora:</h3>
#     No mundo contemporâneo do século XXI já usufruímos e, continuamos a utilizar o petróleo como matéria prima para tornar o mundo cada vez mais tecnológico. Será que o preço da gasolina por litro em um país pode nos revelar algo sobre o índice de desenvolvimento do mesmo? E, como a taxa de crescimento populacional anual do país influencia ou não nesse desenvolvimento?

# %% [markdown]
# <h3>Explicação da pergunta norteadora </h3> <p> Com base em varias combinações de variáveis no Gapminder chamou minha atenção analisar se o preço de gasolina tem alguma relação com o indíce de desenvolvimento humano de um país, uma vez que tal preço esta sujeito a variações dependendo do estado econômico local e da demanda do produto.</p>
# <p>Para a escolha da taxa do crescimento populacional anual como variável deu-se por um racíocinio mais abstrato. Como estamos ficando cada vez mais dependentes da tecnologia é plausível afirmar que ocorreu e, ainda ocorre, uma susbtituição da mão de obra humana pelas máquinas e inteligencias artificiais quando há novos avanços tecnológicos. Desse modo, foi de meu interesse avaliar se tal crescimento ja esteve ou está ligado com o IDH uma vez que com os avanços tecnológicos a mão de obra humana é cada vez mais desnecessária e ineficiente.</p>

# %%
#importando bibliotecas
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#lendo os arquivos
dados_IDH = pd.read_excel("IDH.xlsx")
dados_gasL = pd.read_excel("gasolina-litro.xlsx")
dados_crescimentopop = pd.read_excel("crescimento_populacional_anual.xlsx")

# %%
#Selecionando colunas
idh_2012 = dados_IDH.loc[:,['IDH',2012]]
gasL_2012 = dados_gasL.loc[:,['gasolina/L',2012]]
crescpop_2012 = dados_crescimentopop.loc[:,['CrescPop',2012]]

# %%
#Colocando mesmo índice para todas as variavéis
idh_idx = idh_2012.set_index('IDH')
gasL_idx = gasL_2012.set_index('gasolina/L')
crescpop_idx = crescpop_2012.set_index('CrescPop')

# %%
#Juntando duas variaveis DataFrames
df = idh_idx.join(gasL_idx, how = 'inner',lsuffix ='_idh',rsuffix ='_US$gasolina/L')
#Renomeando
df1=df.rename(columns={'2012_idh':'IDH_2012','2012_US$gasolina/L':'US$ gasolina/L'})
crescpop_idxr = crescpop_idx.rename(columns={2012:'% crescimento populacional anual'})

#Juntando a ultima variavel
data = df1.join(crescpop_idxr, how ='inner')
data
# Out:
#                         IDH_2012  US$ gasolina/L  \
# Afghanistan                0.470           1.280
# Albania                    0.759           1.810
# Algeria                    0.737           0.290
# Andorra                    0.843           1.670
# Angola                     0.523           0.630
# Antigua and Barbuda        0.781             NaN
# Argentina                  0.823           1.460
# Armenia                    0.736           1.250
# Australia                  0.933           1.390
# Austria                    0.887           1.810
# Azerbaijan                 0.745           0.760
# Bahamas                    0.790             NaN
# Bahrain                    0.815           0.270
# Bangladesh                 0.565           1.150
# Barbados                   0.792             NaN
# Belarus                    0.796           0.880
# Belgium                    0.889           2.090
# Belize                     0.706           1.440
# Benin                      0.466           1.240
# Bhutan                     0.589           1.190
# Bolivia                    0.661           0.700
# Bosnia and Herzegovina     0.735           1.590
# Botswana                   0.693           1.230
# Brazil                     0.734           1.390
# Brunei                     0.860           0.430
# Bulgaria                   0.781           1.690
# Burkina Faso               0.392           1.430
# Burundi                    0.398           1.470
# Cambodia                   0.546           1.350
# Cameroon                   0.501           1.100
# ...                          ...             ...
# Sri Lanka                  0.757           1.290
# St. Lucia                  0.734             NaN
# Sudan                      0.478           0.630
# Suriname                   0.719           1.570
# Swaziland                  0.539           1.300
# Sweden                     0.904           2.100
# Switzerland                0.934           1.880
# Syria                      0.635           0.790
# Tajikistan                 0.617           1.450
# Tanzania                   0.513           1.310
# Thailand                   0.733           1.560
# Timor-Leste                0.620           1.650
# Togo                       0.470           1.160
# Trinidad and Tobago        0.773             NaN
# Tunisia                    0.720           0.930
# Turkey                     0.754           2.540
# Turkmenistan               0.678           0.220
# Uganda                     0.478             NaN
# Ukraine                    0.744           1.350
# United Arab Emirates       0.829           0.470
# United Kingdom             0.899           2.170
# United States              0.915           0.970
# Uruguay                    0.788           1.970
# Uzbekistan                 0.681           1.020
# Vanuatu                    0.591             NaN
# Venezuela                  0.770           0.023
# Vietnam                    0.668           1.150
# Yemen                      0.498           0.580
# Zambia                     0.565           1.480
# Zimbabwe                   0.488           1.520
#
#                         % crescimento populacional anual
# Afghanistan                                       3.2700
# Albania                                          -0.1650
# Algeria                                           2.0100
# Andorra                                          -1.5900
# Angola                                            3.5600
# Antigua and Barbuda                               1.1000
# Argentina                                         1.0500
# Armenia                                           0.2200
# Australia                                         1.7900
# Austria                                           0.4560
# Azerbaijan                                        1.3300
# Bahamas                                           1.4800
# Bahrain                                           1.7000
# Bangladesh                                        1.1700
# Barbados                                          0.3500
# Belarus                                          -0.0916
# Belgium                                           0.7260
# Belize                                            2.2600
# Benin                                             2.8000
# Bhutan                                            1.6700
# Bolivia                                           1.5800
# Bosnia and Herzegovina                           -1.1100
# Botswana                                          1.8300
# Brazil                                            0.9390
# Brunei                                            1.4500
# Bulgaria                                         -0.5790
# Burkina Faso                                      3.0000
# Burundi                                           3.0100
# Cambodia                                          1.6300
# Cameroon                                          2.7000
# ...                                                  ...
# Sri Lanka                                         0.5400
# St. Lucia                                         0.5750
# Sudan                                             2.3100
# Suriname                                          1.0300
# Swaziland                                         1.8500
# Sweden                                            0.7400
# Switzerland                                       1.0600
# Syria                                            -2.1500
# Tajikistan                                        2.2700
# Tanzania                                          3.1300
# Thailand                                          0.4640
# Timor-Leste                                       2.2100
# Togo                                              2.6600
# Trinidad and Tobago                               0.5080
# Tunisia                                           1.1600
# Turkey                                            1.5700
# Turkmenistan                                      1.8000
# Uganda                                            3.4000
# Ukraine                                          -0.2470
# United Arab Emirates                              2.5900
# United Kingdom                                    0.6950
# United States                                     0.7460
# Uruguay                                           0.3290
# Uzbekistan                                        1.4700
# Vanuatu                                           2.2900
# Venezuela                                         1.4500
# Vietnam                                           1.1300
# Yemen                                             2.6800
# Zambia                                            3.0100
# Zimbabwe                                          2.2300
#
# [174 rows x 3 columns]

# %%
#Salvando para formato .CSV
datacsv = data.to_csv('Projeto1-Luigi_Portugal_2A', sep=',' ,encoding ='utf-8')
datacsv

# %% [markdown]
# <h3>Gráficos Scatter Plot</h3>

# %%
#Analisando duas variáveis quantitativas com Scatter Plot 
#x - IDH     y - Preço de gasolina/L em doláres
data.plot.scatter(x='US$ gasolina/L', y='IDH_2012', title='IDH X Gasolina/L(US$)')
plt.grid(True)
plt.show()
#x -   IDH   y - Taxa do crescimento populacional anual
data.plot.scatter(x='% crescimento populacional anual', y='IDH_2012', title='IDH X Taxa de crescimento POP anual')
plt.grid(True)
plt.show()
#x - Preço de gasolina/L em doláres    y - Taxa do crescimento populacional anual
data.plot.scatter(y='% crescimento populacional anual', x='US$ gasolina/L', title='Taxa de crescimento POP anual X Gasolina/L(US$)')
plt.grid(True)
plt.show()

# %% [markdown]
# <h2> Coeficiente de Correlação entre os gráficos

# %%
data.corr()
# Out:
#                                   IDH_2012  US$ gasolina/L  \
# IDH_2012                          1.000000        0.221694
# US$ gasolina/L                    0.221694        1.000000
# % crescimento populacional anual -0.441754       -0.401508
#
#                                   % crescimento populacional anual
# IDH_2012                                                 -0.441754
# US$ gasolina/L                                           -0.401508
# % crescimento populacional anual                          1.000000

# %% [markdown]
# <h2>Conclusão:</h2>

# %% [markdown]
# <p> Com base na análise dos gráficos scatter plot juntamente com os respectivos coeficientes de correlação, observamos que o gráfico IDH_2012 x US$ gasolina/L apresenta um baixo coeficiente de correlação (0,22) isso nos revela que o preço por litro de gasolina não apresenta relação significativa com os indices de desenvolvimento humano dos países, assim provando que a hipótese elaborada na pergunta problema do projeto, de que quanto mais alto o IDH mais baixos os preços de gasolina no país, é parcialemente falha uma vez que, os únicos países quem seguem a lógica acima são justo os fornecedores de petróleo no mercado internacional.</p> <p> Já o gráfico IDH_2012 X % crescimento populacional anual tem coeficiente de correlação de -0,44, apesar de ser baixo indicando que as variaveis não tem relação significativa entre elas, com base na análise visual do gráfico podemos concluir que a hipótese proporcionada pela pergunta problema está correta, quanto maior o IDH menor a taxa de crescimento populacional anual de um país.
